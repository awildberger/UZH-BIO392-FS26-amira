# %%
# !pwd
# Out:
# /Users/namiaston/UZH-BIO392-FS26/course-results/Nami_Aston

# %% [markdown]
# First I went to VEP (online) and chose the file: combine_indel_snp_recalibrated.recode.vcf
# Then added the filters: Refseq, HGVS (identifiers), 1000 Genomes global minor allele frequency, 1000 Genomes continental allele frequencies, gnomAD (exomes) allele frequencies, gnomAD (genomes) allele frequencies, AllOfUs allele frequencies. then run.
# Now I chose two variants by filtering (Low and moderate impact)
# Moderate Impact: 	14:19434064-19434064	C	  missense_variant	MODERATE	POTEG	404785	Transcript	NM_001005356.3 protein_coding	1/11 (typed in 14:19434064-19434064 at the top to find information).
# Information to find:
# 1. variant type: missense_variant
# 2. REF and ALT alleles: REF= T, ALT= C
# 3. The Genotype: Genotype: T/C meaning heterozygous
# 4. exact read count supporting the REF and ALT alleles: REF (T) = 189 reads, ALT (C) = 82 reads
# now the screenshot of moderate:

# %% [markdown]
# ![ModerateImpact](moderateimpact.png)

# %% [markdown]
# Low impact: 14:19433942-19433942	C	  synonymous_variant	LOW	POTEG	404785	Transcript	NM_001005356.3	protein_coding	1/11
# 1. variant type: synonymous_variant
# 2. REF and ALT alleles: REF= T, ALT= C
# 3. The Genotype: Genotype: T/C meaning heterozygous
# 4. exact read count supporting the REF and ALT alleles: REF (T) : 489 (80%, 257+, 232- ), ALT (C): 125 (20%, 63+, 62- )
# now the screenshot of low:

# %% [markdown]
# ![LOWIMPACT](lowimpact.png)

# %% [markdown]
# Analyzing the SV in the extract_variants.bam file:
#
# chr1: 37350877 - 37351115: deletion, because you can see through the shift that something is missing. Noticable drop in coverage. Soft clipping shows a deletion pattern (like in the example on slide 31)

# %% [markdown]
# ![chr11](task2aufg1.png)

# %% [markdown]
# chr1: 41369871 - 41369871: insertion: you can see where the colorful sgements are in the middle: something has been inserted (color= it no longer matches the reference, so something "unknown" was added to the chromsome. (inversion ruled out because you would have another indicator for that)). Since the color fuls segments all start at the same base; deduce that this is an inserti

# %% [markdown]
# ![task22](task22.png)

# %% [markdown]
# You can see a duplication here, one the color = green (means RL). Then it looks similar to slide 35 (green bars with gap in between). You can also see the coverage increasing for this region, indication of gain (compared to reference). The green split/aligned reads cluster suggests a junction, this usually marks the edge of a duplicated segment.

# %% [markdown]
# ![task232](task232.png)
